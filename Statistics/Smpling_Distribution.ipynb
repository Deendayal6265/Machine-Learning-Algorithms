# %% [markdown]
# <a href="https://colab.research.google.com/github/Deendayal6265/Machine-Learning-Algorithms/blob/main/Statistics/Smpling_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import statistics

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/weight-height.csv')
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df.Height.mean()    # average height . #population mean
# Out:
# 66.36755975482106

# %%
s= df.Height.sample(n=30,random_state=1)
s.mean()  # sample mean
# Out:
# 66.56023689585659

# %%
sample_means = []
for i in range(1,1000):
  s =  df.Height.sample(n=30)
  sample_means.append(s.mean())

# %%
sample_means
# Out:
# [66.33524632154393,
#  65.52958132999537,
#  65.66833713763212,
#  67.70707519788972,
#  66.45432445752553,
#  65.65638371744392,
#  67.75332211364359,
#  65.69910544746719,
#  66.52009822678824,
#  66.28675372368313,
#  66.0282735888257,
#  67.55924507091534,
#  66.00269310553033,
#  66.65952932708147,
#  65.24703339734947,
#  65.20452637106499,
#  66.47129069520685,
#  66.32497977415163,
#  66.59422357132205,
#  67.05262144517128,
#  65.7652933948631,
#  65.46570436325172,
#  66.2327811299678,
#  65.55094260963219,
#  65.06158228716504,
#  66.22412427811378,
#  65.71797468279597,
#  67.01844106115163,
#  66.00322883061216,
#  65.58390405800766,
#  66.59978437110628,
#  67.0333690445971,
#  67.05752148990481,
#  66.38736820349642,
#  66.9763990117313,
#  65.24482553117646,
#  66.62816909307297,
#  64.93179062059684,
#  65.95657474399695,
#  66.61004051651918,
#  67.46964812455354,
#  65.87479982953003,
#  66.99711798271169,
#  65.87975888817212,
#  66.6884400407584,
# ...

# %%
plt.hist(sample_mean, bins=20)
plt.title("Sample_means",color="red",size=25)
plt.show()

# %%
plt.hist(sample_mean, bins=20,edgecolor='red')
plt.title("Sample_means(Sampling Distribution)",color="red",size=25)
plt.show()

# %%
plt.hist(df.Height, bins=20,edgecolor="black")
plt.title(" Population Distribution",color="red",size=25)
plt.show()
