# %% [markdown]
# <a href="https://colab.research.google.com/github/Deendayal6265/Machine-Learning-Algorithms/blob/main/Decision%20Tree/Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier

# %%
data = datasets.load_iris()
x=data['data']
y=data['target']

print(x.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %%
# split the data into the train and test data . 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=1)

# %%
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # **Export The Graph in pdf format**

# %%
from sklearn.tree import export_graphviz
import pydotplus
dot_data= export_graphviz(model,out_file=None,feature_names = data.feature_names,class_names="data.target_names",
         filled=True,rounded=True) # this give the .data fromat file . 

# convert the file .data to the .pdf 
graph = pydotplus.graph_from_dot_data(dot_data)
graph.write_pdf("irisdecision.pdf")
# Out:
# True

# %% [markdown]
# ![decision pdf.JPG](data:image/jpeg;base64,...)

# %%
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_train,y_train_pred)
# Out:
# array([[37,  0,  0],
#        [ 0, 34,  0],
#        [ 0,  0, 41]])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(confusion_matrix(y_train,y_train_pred),annot=True)
plt.xlabel("y_train")
plt.ylabel("y_pred")
# Out:
# Text(33.0, 0.5, 'y_pred')

# %%
model.score(x_train,y_train)  # score on the training data .
# Out:
# 1.0

# %%
confusion_matrix(y_test,y_test_pred)
# Out:
# array([[13,  0,  0],
#        [ 0, 15,  1],
#        [ 0,  0,  9]])

# %%
model.score(x_test,y_test)
# Out:
# 0.9736842105263158

# %% [markdown]
# # **Or gate example**

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/or.csv')
df
# Out:
#        X      Y     OR
# 0   True   True   True
# 1  False   True   True
# 2   True  False   True
# 3  False  False  False

# %%
df.columns=["x1","x2","y"]
df
# Out:
#       x1     x2      y
# 0   True   True   True
# 1  False   True   True
# 2   True  False   True
# 3  False  False  False

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,2]

# %%
y
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# Name: y, dtype: bool

# %%
from sklearn.preprocessing import LabelEncoder
x.x1=LabelEncoder().fit_transform(x.x1)
x.x2=LabelEncoder().fit_transform(x.x2)
y=LabelEncoder().fit_transform(y)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
x
# Out:
#    x1  x2
# 0   1   1
# 1   0   1
# 2   1   0
# 3   0   0

# %%
y
# Out:
# array([1, 1, 1, 0])

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=1)
x_train
# Out:
#    x1  x2
# 2   1   0
# 0   1   1
# 1   0   1

# %%
model1=DecisionTreeClassifier()
model1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import export_graphviz
import pydotplus
dot_data= export_graphviz(model1,out_file=None,
         filled=True,rounded=True) # this give the .data fromat file . 

# convert the file .data to the .pdf 
graph = pydotplus.graph_from_dot_data(dot_data)
graph.write_pdf("orgate.pdf")
# Out:
# True
